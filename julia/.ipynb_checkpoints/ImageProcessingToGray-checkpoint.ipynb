# %% [markdown]
# # ImagePreProcessing with GrayScale exp
# ### 이미지 데이터를 판단함에 있어서 색깔정보는 필요하지 않을 수 있다는 가정에서 시작

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
from PIL import Image
from skimage.transform import resize
from skimage.io import imread, imsave, imshow
from skimage.color import rgb2gray

# %%
def plot_sample(x, axis):
    # img = x.reshape(96,96)
    axis.imshow(x, cmap='gray')
    axis.axis('off')

def draw_multi_plot(X, y, row_num=4, col_num=4, fig_size=(15,10)):
    fig, axes = plt.subplots(nrows=row_num, ncols=col_num, figsize=fig_size)
    i=0
    for row in axes:
        for each_ax in row:
            plot_sample(X[i], y[i], each_ax)
            i += 1
    plt.tight_layout()

# %%
import os

# %% [markdown]
# ## rgb 를 gray scale 하는 방법은 아래와 같다

# %%
image = imread('train/1.Bmp')
gray_image = rgb2gray(image)
print(gray_image.ndim)
print(gray_image.shape)
imshow(gray_image)
# Out:
# 2
# (214, 207)

# %% [markdown]
# ### 만약 애초에 rgb 가 아닌 ndim=2 짜리는 위의 코드가 통할까?

# %%
image = imread('train/2290.Bmp')
print(image.ndim)
gray_image = rgb2gray(image)
imshow(gray_image)
# Out:
# 2

# %% [markdown]
# ### 다행이 무리없이 통한다. 그럼 위를 바탕으로 gray scale 로 변환 작업을 시작한다.

# %%
if not os.path.exists("myTrainResized_GrayScale"):
    os.makedirs('myTrainResized_GrayScale')
    print(">> make myTrainResized_GrayScale dir")

trainFiles = glob.glob("train/*")
for i, nameFile in enumerate(trainFiles):
    print(nameFile)
    image = imread(nameFile)
    imageResized = resize(image, (20,20))
    gray_image = rgb2gray(imageResized)
    newName = "myTrainResized_GrayScale/" + nameFile.split("/")[-1]
#     print('nameFile.split("/")[:-1] : ', nameFile.split("/")[:-1])
#     print('nameFile.split("/")[-1] : ', nameFile.split("/")[-1])
    print("newName : ", newName)
    imsave (newName, gray_image)
# Out:
# train/1.Bmp
# newName :  myTrainResized_GrayScale/1.Bmp
# train/10.Bmp
# newName :  myTrainResized_GrayScale/10.Bmp
# train/100.Bmp
# newName :  myTrainResized_GrayScale/100.Bmp
# train/1000.Bmp
# newName :  myTrainResized_GrayScale/1000.Bmp
# train/1001.Bmp
# newName :  myTrainResized_GrayScale/1001.Bmp
# train/1002.Bmp
# newName :  myTrainResized_GrayScale/1002.Bmp
# train/1003.Bmp
# newName :  myTrainResized_GrayScale/1003.Bmp
# train/1004.Bmp
# newName :  myTrainResized_GrayScale/1004.Bmp
# train/1005.Bmp
# newName :  myTrainResized_GrayScale/1005.Bmp
# train/1006.Bmp
# newName :  myTrainResized_GrayScale/1006.Bmp
# train/1007.Bmp
# newName :  myTrainResized_GrayScale/1007.Bmp
# train/1008.Bmp
# newName :  myTrainResized_GrayScale/1008.Bmp
# train/1009.Bmp
# newName :  myTrainResized_GrayScale/1009.Bmp
# train/101.Bmp
# newName :  myTrainResized_GrayScale/101.Bmp
# train/1010.Bmp
# newName :  myTrainResized_GrayScale/1010.Bmp
# train/1011.Bmp
# newName :  myTrainResized_GrayScale/1011.Bmp
# train/1012.Bmp
# newName :  myTrainResized_GrayScale/1012.Bmp
# train/1013.Bmp
# newName :  myTrainResized_GrayScale/1013.Bmp
# train/1014.Bmp
# newName :  myTrainResized_GrayScale/1014.Bmp
# train/1015.Bmp
# newName :  myTrainResized_GrayScale/1015.Bmp
# train/1016.Bmp
# newName :  myTrainResized_GrayScale/1016.Bmp
# train/1017.Bmp
# newName :  myTrainResized_GrayScale/1017.Bmp
# train/1018.Bmp
# newName :  myTrainResized_GrayScale/1018.Bmp
# train/1019.Bmp
# newName :  myTrainResized_GrayScale/1019.Bmp
# train/102.Bmp
# newName :  myTrainResized_GrayScale/102.Bmp
# train/1020.Bmp
# newName :  myTrainResized_GrayScale/1020.Bmp
# train/1021.Bmp
# newName :  myTrainResized_GrayScale/1021.Bmp
# train/1022.Bmp
# newName :  myTrainResized_GrayScale/1022.Bmp
# train/1023.Bmp
# newName :  myTrainResized_GrayScale/1023.Bmp
# train/1024.Bmp
# newName :  myTrainResized_GrayScale/1024.Bmp
# train/1025.Bmp
# newName :  myTrainResized_GrayScale/1025.Bmp
# train/1026.Bmp
# newName :  myTrainResized_GrayScale/1026.Bmp
# train/1027.Bmp
# newName :  myTrainResized_GrayScale/1027.Bmp
# train/1028.Bmp
# newName :  myTrainResized_GrayScale/1028.Bmp
# train/1029.Bmp
# newName :  myTrainResized_GrayScale/1029.Bmp
# train/103.Bmp
# newName :  myTrainResized_GrayScale/103.Bmp
# train/1030.Bmp
# newName :  myTrainResized_GrayScale/1030.Bmp
# train/1031.Bmp
# newName :  myTrainResized_GrayScale/1031.Bmp
# train/1032.Bmp
# newName :  myTrainResized_GrayScale/1032.Bmp
# train/1033.Bmp
# newName :  myTrainResized_GrayScale/1033.Bmp
# train/1034.Bmp
# newName :  myTrainResized_GrayScale/1034.Bmp
# train/1035.Bmp
# newName :  myTrainResized_GrayScale/1035.Bmp
# train/1036.Bmp
# newName :  myTrainResized_GrayScale/1036.Bmp
# train/1037.Bmp
# newName :  myTrainResized_GrayScale/1037.Bmp
# train/1038.Bmp
# newName :  myTrainResized_GrayScale/1038.Bmp
# train/1039.Bmp
# newName :  myTrainResized_GrayScale/1039.Bmp
# train/104.Bmp
# newName :  myTrainResized_GrayScale/104.Bmp
# train/1040.Bmp
# newName :  myTrainResized_GrayScale/1040.Bmp
# train/1041.Bmp
# newName :  myTrainResized_GrayScale/1041.Bmp
# train/1042.Bmp
# newName :  myTrainResized_GrayScale/1042.Bmp
# train/1043.Bmp
# newName :  myTrainResized_GrayScale/1043.Bmp
# train/1044.Bmp
# newName :  myTrainResized_GrayScale/1044.Bmp
# train/1045.Bmp
# newName :  myTrainResized_GrayScale/1045.Bmp
# train/1046.Bmp
# newName :  myTrainResized_GrayScale/1046.Bmp
# train/1047.Bmp
# newName :  myTrainResized_GrayScale/1047.Bmp
# train/1048.Bmp
# newName :  myTrainResized_GrayScale/1048.Bmp
# train/1049.Bmp
# newName :  myTrainResized_GrayScale/1049.Bmp
# train/105.Bmp
# newName :  myTrainResized_GrayScale/105.Bmp
# train/1050.Bmp
# newName :  myTrainResized_GrayScale/1050.Bmp
# train/1051.Bmp
# newName :  myTrainResized_GrayScale/1051.Bmp
# train/1052.Bmp
# newName :  myTrainResized_GrayScale/1052.Bmp
# train/1053.Bmp
# newName :  myTrainResized_GrayScale/1053.Bmp
# train/1054.Bmp
# newName :  myTrainResized_GrayScale/1054.Bmp
# train/1055.Bmp
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# newName :  myTrainResized_GrayScale/1055.Bmp
# train/1056.Bmp
# newName :  myTrainResized_GrayScale/1056.Bmp
# train/1057.Bmp
# newName :  myTrainResized_GrayScale/1057.Bmp
# train/1058.Bmp
# newName :  myTrainResized_GrayScale/1058.Bmp
# train/1059.Bmp
# newName :  myTrainResized_GrayScale/1059.Bmp
# train/106.Bmp
# newName :  myTrainResized_GrayScale/106.Bmp
# train/1060.Bmp
# newName :  myTrainResized_GrayScale/1060.Bmp
# train/1061.Bmp
# newName :  myTrainResized_GrayScale/1061.Bmp
# train/1062.Bmp
# newName :  myTrainResized_GrayScale/1062.Bmp
# train/1063.Bmp
# newName :  myTrainResized_GrayScale/1063.Bmp
# train/1064.Bmp
# newName :  myTrainResized_GrayScale/1064.Bmp
# train/1065.Bmp
# newName :  myTrainResized_GrayScale/1065.Bmp
# train/1066.Bmp
# newName :  myTrainResized_GrayScale/1066.Bmp
# train/1067.Bmp
# newName :  myTrainResized_GrayScale/1067.Bmp
# train/1068.Bmp
# newName :  myTrainResized_GrayScale/1068.Bmp
# train/1069.Bmp
# newName :  myTrainResized_GrayScale/1069.Bmp
# train/107.Bmp
# newName :  myTrainResized_GrayScale/107.Bmp
# train/1070.Bmp
# newName :  myTrainResized_GrayScale/1070.Bmp
# train/1071.Bmp
# newName :  myTrainResized_GrayScale/1071.Bmp
# train/1072.Bmp
# newName :  myTrainResized_GrayScale/1072.Bmp
# train/1073.Bmp
# newName :  myTrainResized_GrayScale/1073.Bmp
# train/1074.Bmp
# newName :  myTrainResized_GrayScale/1074.Bmp
# train/1075.Bmp
# newName :  myTrainResized_GrayScale/1075.Bmp
# train/1076.Bmp
# newName :  myTrainResized_GrayScale/1076.Bmp
# train/1077.Bmp
# newName :  myTrainResized_GrayScale/1077.Bmp
# train/1078.Bmp
# newName :  myTrainResized_GrayScale/1078.Bmp
# train/1079.Bmp
# newName :  myTrainResized_GrayScale/1079.Bmp
# train/108.Bmp
# newName :  myTrainResized_GrayScale/108.Bmp
# train/1080.Bmp
# newName :  myTrainResized_GrayScale/1080.Bmp
# train/1081.Bmp
# newName :  myTrainResized_GrayScale/1081.Bmp
# train/1082.Bmp
# newName :  myTrainResized_GrayScale/1082.Bmp
# train/1083.Bmp
# newName :  myTrainResized_GrayScale/1083.Bmp
# train/1084.Bmp
# newName :  myTrainResized_GrayScale/1084.Bmp
# train/1085.Bmp
# newName :  myTrainResized_GrayScale/1085.Bmp
# train/1086.Bmp
# newName :  myTrainResized_GrayScale/1086.Bmp
# train/1087.Bmp
# newName :  myTrainResized_GrayScale/1087.Bmp
# train/1088.Bmp
# newName :  myTrainResized_GrayScale/1088.Bmp
# train/1089.Bmp
# newName :  myTrainResized_GrayScale/1089.Bmp
# train/109.Bmp
# newName :  myTrainResized_GrayScale/109.Bmp
# train/1090.Bmp
# newName :  myTrainResized_GrayScale/1090.Bmp
# train/1091.Bmp
# newName :  myTrainResized_GrayScale/1091.Bmp
# train/1092.Bmp
# newName :  myTrainResized_GrayScale/1092.Bmp
# train/1093.Bmp
# newName :  myTrainResized_GrayScale/1093.Bmp
# train/1094.Bmp
# newName :  myTrainResized_GrayScale/1094.Bmp
# train/1095.Bmp
# newName :  myTrainResized_GrayScale/1095.Bmp
# train/1096.Bmp
# newName :  myTrainResized_GrayScale/1096.Bmp
# train/1097.Bmp
# newName :  myTrainResized_GrayScale/1097.Bmp
# train/1098.Bmp
# newName :  myTrainResized_GrayScale/1098.Bmp
# train/1099.Bmp
# newName :  myTrainResized_GrayScale/1099.Bmp
# train/11.Bmp
# newName :  myTrainResized_GrayScale/11.Bmp
# train/110.Bmp
# newName :  myTrainResized_GrayScale/110.Bmp
# train/1100.Bmp
# newName :  myTrainResized_GrayScale/1100.Bmp
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# train/1101.Bmp
# newName :  myTrainResized_GrayScale/1101.Bmp
# train/1102.Bmp
# newName :  myTrainResized_GrayScale/1102.Bmp
# train/1103.Bmp
# newName :  myTrainResized_GrayScale/1103.Bmp
# train/1104.Bmp
# newName :  myTrainResized_GrayScale/1104.Bmp
# train/1105.Bmp
# newName :  myTrainResized_GrayScale/1105.Bmp
# train/1106.Bmp
# newName :  myTrainResized_GrayScale/1106.Bmp
# train/1107.Bmp
# newName :  myTrainResized_GrayScale/1107.Bmp
# train/1108.Bmp
# newName :  myTrainResized_GrayScale/1108.Bmp
# train/1109.Bmp
# newName :  myTrainResized_GrayScale/1109.Bmp
# train/111.Bmp
# newName :  myTrainResized_GrayScale/111.Bmp
# train/1110.Bmp
# newName :  myTrainResized_GrayScale/1110.Bmp
# train/1111.Bmp
# newName :  myTrainResized_GrayScale/1111.Bmp
# train/1112.Bmp
# newName :  myTrainResized_GrayScale/1112.Bmp
# train/1113.Bmp
# newName :  myTrainResized_GrayScale/1113.Bmp
# train/1114.Bmp
# newName :  myTrainResized_GrayScale/1114.Bmp
# train/1115.Bmp
# newName :  myTrainResized_GrayScale/1115.Bmp
# train/1116.Bmp
# newName :  myTrainResized_GrayScale/1116.Bmp
# train/1117.Bmp
# newName :  myTrainResized_GrayScale/1117.Bmp
# train/1118.Bmp
# newName :  myTrainResized_GrayScale/1118.Bmp
# train/1119.Bmp
# newName :  myTrainResized_GrayScale/1119.Bmp
# train/112.Bmp
# newName :  myTrainResized_GrayScale/112.Bmp
# train/1120.Bmp
# newName :  myTrainResized_GrayScale/1120.Bmp
# train/1121.Bmp
# newName :  myTrainResized_GrayScale/1121.Bmp
# train/1122.Bmp
# newName :  myTrainResized_GrayScale/1122.Bmp
# train/1123.Bmp
# newName :  myTrainResized_GrayScale/1123.Bmp
# train/1124.Bmp
# newName :  myTrainResized_GrayScale/1124.Bmp
# train/1125.Bmp
# newName :  myTrainResized_GrayScale/1125.Bmp
# train/1126.Bmp
# newName :  myTrainResized_GrayScale/1126.Bmp
# train/1127.Bmp
# newName :  myTrainResized_GrayScale/1127.Bmp
# train/1128.Bmp
# newName :  myTrainResized_GrayScale/1128.Bmp
# train/1129.Bmp
# newName :  myTrainResized_GrayScale/1129.Bmp
# train/113.Bmp
# newName :  myTrainResized_GrayScale/113.Bmp
# train/1130.Bmp
# newName :  myTrainResized_GrayScale/1130.Bmp
# train/1131.Bmp
# newName :  myTrainResized_GrayScale/1131.Bmp
# train/1132.Bmp
# newName :  myTrainResized_GrayScale/1132.Bmp
# train/1133.Bmp
# newName :  myTrainResized_GrayScale/1133.Bmp
# train/1134.Bmp
# newName :  myTrainResized_GrayScale/1134.Bmp
# train/1135.Bmp
# newName :  myTrainResized_GrayScale/1135.Bmp
# train/1136.Bmp
# newName :  myTrainResized_GrayScale/1136.Bmp
# train/1137.Bmp
# newName :  myTrainResized_GrayScale/1137.Bmp
# train/1138.Bmp
# newName :  myTrainResized_GrayScale/1138.Bmp
# train/1139.Bmp
# newName :  myTrainResized_GrayScale/1139.Bmp
# train/114.Bmp
# newName :  myTrainResized_GrayScale/114.Bmp
# train/1140.Bmp
# newName :  myTrainResized_GrayScale/1140.Bmp
# train/1141.Bmp
# newName :  myTrainResized_GrayScale/1141.Bmp
# train/1142.Bmp
# newName :  myTrainResized_GrayScale/1142.Bmp
# train/1143.Bmp
# newName :  myTrainResized_GrayScale/1143.Bmp
# train/1144.Bmp
# newName :  myTrainResized_GrayScale/1144.Bmp
# train/1145.Bmp
# newName :  myTrainResized_GrayScale/1145.Bmp
# train/1146.Bmp
# newName :  myTrainResized_GrayScale/1146.Bmp
# train/1147.Bmp
# newName :  myTrainResized_GrayScale/1147.Bmp
# train/1148.Bmp
# newName :  myTrainResized_GrayScale/1148.Bmp
# train/1149.Bmp
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# newName :  myTrainResized_GrayScale/1149.Bmp
# train/115.Bmp
# newName :  myTrainResized_GrayScale/115.Bmp
# train/1150.Bmp
# newName :  myTrainResized_GrayScale/1150.Bmp
# train/1151.Bmp
# newName :  myTrainResized_GrayScale/1151.Bmp
# train/1152.Bmp
# newName :  myTrainResized_GrayScale/1152.Bmp
# train/1153.Bmp
# newName :  myTrainResized_GrayScale/1153.Bmp
# train/1154.Bmp
# newName :  myTrainResized_GrayScale/1154.Bmp
# train/1155.Bmp
# newName :  myTrainResized_GrayScale/1155.Bmp
# train/1156.Bmp
# newName :  myTrainResized_GrayScale/1156.Bmp
# train/1157.Bmp
# newName :  myTrainResized_GrayScale/1157.Bmp
# train/1158.Bmp
# newName :  myTrainResized_GrayScale/1158.Bmp
# train/1159.Bmp
# newName :  myTrainResized_GrayScale/1159.Bmp
# train/116.Bmp
# newName :  myTrainResized_GrayScale/116.Bmp
# train/1160.Bmp
# newName :  myTrainResized_GrayScale/1160.Bmp
# train/1161.Bmp
# newName :  myTrainResized_GrayScale/1161.Bmp
# train/1162.Bmp
# newName :  myTrainResized_GrayScale/1162.Bmp
# train/1163.Bmp
# newName :  myTrainResized_GrayScale/1163.Bmp
# train/1164.Bmp
# newName :  myTrainResized_GrayScale/1164.Bmp
# train/1165.Bmp
# newName :  myTrainResized_GrayScale/1165.Bmp
# train/1166.Bmp
# ...
# newName :  myTrainResized_GrayScale/960.Bmp
# train/961.Bmp
# newName :  myTrainResized_GrayScale/961.Bmp
# train/962.Bmp
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# newName :  myTrainResized_GrayScale/962.Bmp
# train/963.Bmp
# newName :  myTrainResized_GrayScale/963.Bmp
# train/964.Bmp
# newName :  myTrainResized_GrayScale/964.Bmp
# train/965.Bmp
# newName :  myTrainResized_GrayScale/965.Bmp
# train/966.Bmp
# newName :  myTrainResized_GrayScale/966.Bmp
# train/967.Bmp
# newName :  myTrainResized_GrayScale/967.Bmp
# train/968.Bmp
# newName :  myTrainResized_GrayScale/968.Bmp
# train/969.Bmp
# newName :  myTrainResized_GrayScale/969.Bmp
# train/97.Bmp
# newName :  myTrainResized_GrayScale/97.Bmp
# train/970.Bmp
# newName :  myTrainResized_GrayScale/970.Bmp
# train/971.Bmp
# newName :  myTrainResized_GrayScale/971.Bmp
# train/972.Bmp
# newName :  myTrainResized_GrayScale/972.Bmp
# train/973.Bmp
# newName :  myTrainResized_GrayScale/973.Bmp
# train/974.Bmp
# newName :  myTrainResized_GrayScale/974.Bmp
# train/975.Bmp
# newName :  myTrainResized_GrayScale/975.Bmp
# train/976.Bmp
# newName :  myTrainResized_GrayScale/976.Bmp
# train/977.Bmp
# newName :  myTrainResized_GrayScale/977.Bmp
# train/978.Bmp
# newName :  myTrainResized_GrayScale/978.Bmp
# train/979.Bmp
# newName :  myTrainResized_GrayScale/979.Bmp
# train/98.Bmp
# newName :  myTrainResized_GrayScale/98.Bmp
# train/980.Bmp
# newName :  myTrainResized_GrayScale/980.Bmp
# train/981.Bmp
# newName :  myTrainResized_GrayScale/981.Bmp
# train/982.Bmp
# newName :  myTrainResized_GrayScale/982.Bmp
# train/983.Bmp
# newName :  myTrainResized_GrayScale/983.Bmp
# train/984.Bmp
# newName :  myTrainResized_GrayScale/984.Bmp
# train/985.Bmp
# newName :  myTrainResized_GrayScale/985.Bmp
# train/986.Bmp
# newName :  myTrainResized_GrayScale/986.Bmp
# train/987.Bmp
# newName :  myTrainResized_GrayScale/987.Bmp
# train/988.Bmp
# newName :  myTrainResized_GrayScale/988.Bmp
# train/989.Bmp
# newName :  myTrainResized_GrayScale/989.Bmp
# train/99.Bmp
# newName :  myTrainResized_GrayScale/99.Bmp
# train/990.Bmp
# newName :  myTrainResized_GrayScale/990.Bmp
# train/991.Bmp
# newName :  myTrainResized_GrayScale/991.Bmp
# train/992.Bmp
# newName :  myTrainResized_GrayScale/992.Bmp
# train/993.Bmp
# newName :  myTrainResized_GrayScale/993.Bmp
# train/994.Bmp
# newName :  myTrainResized_GrayScale/994.Bmp
# train/995.Bmp
# newName :  myTrainResized_GrayScale/995.Bmp
# train/996.Bmp
# newName :  myTrainResized_GrayScale/996.Bmp
# train/997.Bmp
# newName :  myTrainResized_GrayScale/997.Bmp
# train/998.Bmp
# newName :  myTrainResized_GrayScale/998.Bmp
# train/999.Bmp
# newName :  myTrainResized_GrayScale/999.Bmp
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))
# /Users/myZZUNG/myworkspace/kaggle-study/jupyter/lib/python3.5/site-packages/skimage/util/dtype.py:110: UserWarning: Possible precision loss when converting from float64 to uint8
#   "%s to %s" % (dtypeobj_in, dtypeobj))

# %% [markdown]
# ### 제대로 만들어졌는지 확인해보자

# %%
trainLabels = pd.read_csv('trainLabels.csv')
trainLabels.head(5)
# Out:
#    ID Class
# 0   1     n
# 1   2     8
# 2   3     T
# 3   4     I
# 4   5     R

# %%
trainX = []
trainY_array = []
trainFiles = glob.glob("myTrainResized_GrayScale/*")
for i, nameFile in enumerate(trainFiles):
    # print(nameFile)
    id_col = int(nameFile.split('/')[-1].split('.')[0])
    trainY_array.append(trainLabels[trainLabels['ID'] == id_col]['Class'].item())
    image = imread(nameFile)
    trainX.append(image)
trainX = np.array(trainX)
print("trainX.shape", trainX.shape)
trainY = np.array(trainY_array)
trainY = pd.get_dummies(trainY).values
print("trainY.shape", trainY.shape)
